# %%
import pandas as pd
import matplotlib as plt 
import numpy as np
import glob

# %%
df= pd.read_csv('train.csv')
df.head(10)
# Out:
#    stock_id  time_id    target
# 0         0        5  0.004136
# 1         0       11  0.001445
# 2         0       16  0.002168
# 3         0       31  0.002195
# 4         0       62  0.001747
# 5         0       72  0.004912
# 6         0       97  0.009388
# 7         0      103  0.004120
# 8         0      109  0.002182
# 9         0      123  0.002669

# %%
df['stock_id']
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#          ...
# 428927    126
# 428928    126
# 428929    126
# 428930    126
# 428931    126
# Name: stock_id, Length: 428932, dtype: int64

# %%
df.shape
# Out:
# (428932, 3)

# %%
df.isnull().sum()
# Out:
# stock_id    0
# time_id     0
# target      0
# dtype: int64

# %%
import pyarrow.parquet as pa

df=pd.read_parquet('book_train/stock_id=0/c439ef22282f412ba39e9137a3fdabac.parquet')
df.head(10)
# Out:
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    1.001422    1.002301     1.00137    1.002353
# 1        5                  1    1.001422    1.002301     1.00137    1.002353
# 2        5                  5    1.001422    1.002301     1.00137    1.002405
# 3        5                  6    1.001422    1.002301     1.00137    1.002405
# 4        5                  7    1.001422    1.002301     1.00137    1.002405
# 5        5                 11    1.001422    1.002301     1.00137    1.002405
# 6        5                 12    1.001422    1.002301     1.00137    1.002405
# 7        5                 14    1.001422    1.002301     1.00137    1.002405
# 8        5                 15    1.001422    1.002301     1.00137    1.002405
# 9        5                 16    1.001422    1.002301     1.00137    1.002405
#
#    bid_size1  ask_size1  bid_size2  ask_size2
# 0          3        226          2        100
# 1          3        100          2        100
# 2          3        100          2        100
# 3          3        126          2        100
# 4          3        126          2        100
# 5          3        100          2        100
# 6          3        126          2        100
# 7          3        126          2        100
# 8          3        126          2        100
# 9          3        126          2        100

# %%
df['bid_price1'][2]
# Out:
# 1.0014222

# %%
df[df['time_id']==11]
# Out:
#      time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 302       11                  0    0.999473    1.000176    0.999423
# 303       11                  3    0.999473    1.000176    0.999423
# 304       11                 13    0.999473    1.000326    0.999423
# 305       11                 18    0.999473    1.000025    0.999423
# 306       11                 28    0.999473    1.000326    0.999423
# ..       ...                ...         ...         ...         ...
# 497       11                570    1.000025    1.000778    0.999975
# 498       11                574    1.000025    1.000778    0.999975
# 499       11                584    1.000276    1.000778    0.999975
# 500       11                585    1.000276    1.000778    0.999975
# 501       11                596    1.000276    1.000778    0.999975
#
#      ask_price2  bid_size1  ask_size1  bid_size2  ask_size2      wap1
# 302    1.000376        205        100         20         30  0.999945
# 303    1.000376        200        100         20         30  0.999941
# 304    1.000376        200        100         20         30  1.000042
# 305    1.000376        200        100         20         30  0.999841
# 306    1.000376        200        100         20         30  1.000042
# ..          ...        ...        ...        ...        ...       ...
# 497    1.000878        309         10        120         44  1.000754
# 498    1.000878        200         10        120         44  1.000742
# 499    1.000878          1         32        120         84  1.000291
# 500    1.000878          1         32        120         44  1.000291
# 501    1.000878          2         32        120         52  1.000306
#
# [200 rows x 11 columns]

# %%
'''
def get_book_data(Type, stock):
    
    # Path
    PATH_BOOK='http://localhost:8888/tree/Desktop/machine_learning/Volatility%20prediction/book_train'
    #PATH_TRADE='../input/optiver-realized-volatility-prediction/trade_'
    
    # Import book data
    filename=glob.glob(PATH_BOOK+f'**{Type}.parquet/stock_id={stock}/*.parquet')
    filename=np.array(filename)[0]  
    df=pd.read_parquet(filename)
'''
# Out:
# "\ndef get_book_data(Type, stock):\n    \n    # Path\n    PATH_BOOK='http://localhost:8888/tree/Desktop/machine_learning/Volatility%20prediction/book_train'\n    #PATH_TRADE='../input/optiver-realized-volatility-prediction/trade_'\n    \n    # Import book data\n    filename=glob.glob(PATH_BOOK+f'**{Type}.parquet/stock_id={stock}/*.parquet')\n    filename=np.array(filename)[0]  \n    df=pd.read_parquet(filename)\n"

# %%
wap=[]
for i in range(df.shape[0]):
    
    wap1=(df['bid_price1'][i]*df['ask_size1'][i]+df['ask_price1'][i]*df['bid_size1'][i])/(df['bid_size1'][i]+df['ask_size1'][i])
    wap.append(wap1)

# %%
df['wap1']=wap
df.head()
# Out:
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    1.001422    1.002301     1.00137    1.002353
# 1        5                  1    1.001422    1.002301     1.00137    1.002353
# 2        5                  5    1.001422    1.002301     1.00137    1.002405
# 3        5                  6    1.001422    1.002301     1.00137    1.002405
# 4        5                  7    1.001422    1.002301     1.00137    1.002405
#
#    bid_size1  ask_size1  bid_size2  ask_size2      wap1
# 0          3        226          2        100  1.001434
# 1          3        100          2        100  1.001448
# 2          3        100          2        100  1.001448
# 3          3        126          2        100  1.001443
# 4          3        126          2        100  1.001443

# %%
len(pd.unique(df['time_id']))
# Out:
# 3830

# %%
df_time_id_5 = df[df['time_id']==5]

# %%
df_time_id_5.shape
# Out:
# (302, 11)

# %%
import plotly.express as px
fig = px.line(df_time_id_5, x="seconds_in_bucket", y="wap1", title='WAP of stock_id_0, time_id_5')
fig.show()
# Out:
# <div>                            <div id="59a32bf5-2171-4469-85e6-2c5c15b97bbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59a32bf5-2171-4469-85e6-2c5c15b97bbd")) {                    Plotly.newPlot(                        "59a32bf5-2171-4469-85e6-2c5c15b97bbd",                        [{"hovertemplate":"seconds_in_bucket=%{x}\u003cbr\u003ewap1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[0,1,5,6,7,11,12,14,15,16,17,18,19,21,24,25,44,46,47,48,50,51,55,57,59,60,63,68,69,78,79,81,83,85,90,92,93,94,97,98,101,103,105,106,110,111,113,114,115,118,119,122,123,124,126,127,128,129,132,133,134,138,140,141,143,144,145,147,148,149,150,151,152,153,154,158,159,160,161,164,165,166,167,168,169,171,173,174,175,177,178,181,182,183,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201
_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 1          5                  1    1.001422    1.002301    1.001370
# 2          5                  5    1.001422    1.002301    1.001370
# 3          5                  6    1.001422    1.002301    1.001370
# 4          5                  7    1.001422    1.002301    1.001370
# 5          5                 11    1.001422    1.002301    1.001370
# ..       ...                ...         ...         ...         ...
# 297        5                585    1.003129    1.003749    1.003025
# 298        5                586    1.003129    1.003749    1.002612
# 299        5                587    1.003129    1.003749    1.003025
# 300        5                588    1.003129    1.003749    1.002612
# 301        5                593    1.003129    1.003749    1.003025
#
#      ask_price2  bid_size1  ask_size1  bid_size2  ask_size2      wap1  \
# 1      1.002353          3        100          2        100  1.001448
# 2      1.002405          3        100          2        100  1.001448
# 3      1.002405          3        126          2        100  1.001443
# 4      1.002405          3        126          2        100  1.001443
# 5      1.002405          3        100          2        100  1.001448
# ..          ...        ...        ...        ...        ...       ...
# 297    1.003801        100          3         26          3  1.003731
# 298    1.003801        100          3          2          3  1.003731
# 299    1.003801        100          3         26          3  1.003731
# 300    1.003801        100          3          2          3  1.003731
# 301    1.003801        100          3         26          3  1.003731
#
#      log_return  volatility
# 1      0.000014    0.004499
# 2      0.000000    0.004499
# 3     -0.000005    0.004499
# 4      0.000000    0.004499
# 5      0.000005    0.004499
# ..          ...         ...
# 297    0.000245    0.004499
# 298    0.000000    0.004499
# 299    0.000000    0.004499
# 300    0.000000    0.004499
# 301    0.000000    0.004499
#
# [301 rows x 13 columns]

# %%
fig = px.line(df_time_id_5, x="seconds_in_bucket", y="log_return", title='log_return of stock_id_0, time_id_5')
fig.show()
# Out:
# <div>                            <div id="2085dd3a-a301-4efd-81a7-f4c6bf35a884" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2085dd3a-a301-4efd-81a7-f4c6bf35a884")) {                    Plotly.newPlot(                        "2085dd3a-a301-4efd-81a7-f4c6bf35a884",                        [{"hovertemplate":"seconds_in_bucket=%{x}\u003cbr\u003elog_return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[0,1,5,6,7,11,12,14,15,16,17,18,19,21,24,25,44,46,47,48,50,51,55,57,59,60,63,68,69,78,79,81,83,85,90,92,93,94,97,98,101,103,105,106,110,111,113,114,115,118,119,122,123,124,126,127,128,129,132,133,134,138,140,141,143,144,145,147,148,149,150,151,152,153,154,158,159,160,161,164,165,166,167,168,169,171,173,174,175,177,178,181,182,183,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,203,204,205,206,207,209,211,212,213,215,216,218,219,221,222,223,224,225,226,227,228,230,231,232,233,234,235,237,239,248,253,254,255,256,257,258,259,260,263,264,265,269,278,282,283,287,288,290,293,295,296,298,301,303,304,305,306,308,309,310,311,312,313,314,316,322,323,329,331,336,338,340,345,348,350,353,356,363,365,366,367,374,378,380,382,385,386,388,389,391,394,398,399,400,401,402,403,404,406,410,411,416,425,426,427,428,430,431,433,434,435,437,438,440,441,442,443,444,445,446,447,448,449,464,465,466,467,470,471,472,473,474,475,477,478,479,488,489,495,496,498,503,511,513,514,515,516,518,519,520,521,522,523,524,525,526,528,531,532,534,535,538,539,540,541,542,545,546,548,549,550,551,552,555,558,561,562,563,571,572,573,574,575,579,581,584,585,586,587,588,593],"xaxis":"x","y":[null,1.4069088671764826e-05,0.0,-5.1536225261729005e-06,0.0,5